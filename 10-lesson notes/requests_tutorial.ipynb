# %% [markdown]
# ## Python `Requests`

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests) (2026.6.17)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

# %%
requests.get('https://example.com')
# Out:
# <Response [200]>

# %%
res = requests.get('https://example.com')
type(res)
# Out:
# requests.models.Response

# %%
res.status_code
# Out:
# 200

# %%
if res.status_code == 200:
    print('Success!')
elif res.status_code == 404:
    print('Not found.')
# Out:
# Success!

# %%
res.raise_for_status()

# %%
import requests
from requests.exceptions import HTTPError

for url in ['https://api.github.com', 'https://api.github.com/invalid']:
    try:
        response = requests.get(url)
        response.raise_for_status()
    except HTTPError as http_err:
        print(f'HTTP error occured: {http_err}')
    except Exception as err:
        print(f'other error occurred: {err}')
    else:
        print('Success!')
# Out:
# HTTP error occured: 403 Client Error: rate limit exceeded for url: https://api.github.com/
# HTTP error occured: 403 Client Error: rate limit exceeded for url: https://api.github.com/invalid

# %% [markdown]
# ## Content

# %%
response=requests.get('https://cbu.uz/oz/financial-stability/report/')
response.content
# Out:
# b'<!DOCTYPE html>\n<html lang="oz" data-site-dir="/oz/">\n<head><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width, initial-scale=1"><title>\xd0\x9c\xd0\xbe\xd0\xbb\xd0\xb8\xd1\x8f\xd0\xb2\xd0\xb8\xd0\xb9 \xd0\xb1\xd0\xb0\xd1\x80\xd2\x9b\xd0\xb0\xd1\x80\xd0\xbe\xd1\x80\xd0\xbb\xd0\xb8\xd0\xba \xd1\x88\xd0\xb0\xd1\x80\xd2\xb3\xd0\xb8 - \xd0\x8e\xd0\xb7\xd0\xb1\xd0\xb5\xd0\xba\xd0\xb8\xd1\x81\xd1\x82\xd0\xbe\xd0\xbd \xd0\xa0\xd0\xb5\xd1\x81\xd0\xbf\xd1\x83\xd0\xb1\xd0\xbb\xd0\xb8\xd0\xba\xd0\xb0\xd1\x81\xd0\xb8 \xd0\x9c\xd0\xb0\xd1\x80\xd0\xba\xd0\xb0\xd0\xb7\xd0\xb8\xd0\xb9 \xd0\xb1\xd0\xb0\xd0\xbd\xd0\xba\xd0\xb8</title><link rel="apple-touch-icon" sizes="180x180" href="/favicons/apple-touch-icon.png"><link rel="icon" type="image/svg+xml" sizes="120x120" href="/favicons/favicon-120x120.svg"><link rel="icon" type="image/png" sizes="96x96" href="/favicons/favicon-96x96.png"><link rel="icon" type="image/png" sizes="32x32" href="/favicons/favicon-32x32.png"><link rel="icon" type="image/png" sizes="16x16" href="/favicons/favicon-16x16.png"><link rel="manifest" href="/favicons/site.webmanifest"><meta name="msapplication-TileColor" content="#ffc700"><meta name="theme-color" content="#ffc700"><meta name="msapplication-config" content="/favicons/browserconfig.xml"><meta name="format-detection" content="telephone=no"><meta name="format-detection" content="date=no"><meta name="format-detection" content="address=no"><meta name="format-detection" content="email=no"><meta name="format-detection" content="telephone=no,date=no,address=no,email=no,url=no"><link href="/bitrix/templates/main/css/jquery.reject-1.1.0.min.css" type="text/css" rel="stylesheet" data-skip-moving="true">\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n<meta name="robots" content="index, follow" />\n<script data-skip-moving="true">(function(w, d, n) {var cl = "bx-core";var ht = d.documentElement;var htc = ht ? ht.className : undefined;if (htc === undefined || htc.indexOf(cl) !== -1){return;}var ua = n.userAgent;if (/(iPad;)|(iPhone;)/i.test(ua)){cl += " bx-ios";}else if (/Windows/i.test(ua)){cl += \' bx-win\';}else if (/Macintosh/i.test(ua)){cl += " bx-mac";}else if (/Linux/i.test(ua) && !/Android/i.test(ua)){cl += " bx-linux";}else if (/Android/i.test(ua)){cl += " bx-android";}cl += (/(ipad|iphone|android|mobile|touch)/i.test(ua) ? " bx-touch" : " bx-no-touch");cl += w.devicePixelRatio && w.devicePixelRatio >= 2? " bx-retina": " bx-no-retina";if (/Safari/i.test(ua) && !/Chrome/i.test(ua)){cl += " bx-safari";}else if (/AppleWebKit/.test(ua)){cl += " bx-chrome";}else if (/Opera/.test(ua)){cl += " bx-opera";}else if (/Firefox/.test(ua)){cl += " bx-firefox";}ht.className = htc ? htc + " " + cl : cl;})(window, document, navigator);</script>\n\n\n<link href="/bitrix/js/ui/design-tokens/dist/ui.design-tokens.min.css?172977453223463" type="text/css" rel="stylesheet"/>\n<link href="/bitrix/js/ui/fonts/opensans/ui.font.opensans.min.css?16778425832320" type="text/css" rel="stylesheet"/>\n<link href="/bitrix/js/main/popup/dist/main.popup.bundle.min.css?176951421628056" type="text/css" rel="stylesheet"/>\n<link href="/bitrix/js/altasib.errorsend/css/window.css?1694603798910" type="text/css" rel="stylesheet"/>\n<link href="/bitrix/cache/css/s4/main/template_1b6fdbb01d9a6a32a35de54a35f995e8/template_1b6fdbb01d9a6a32a35de54a35f995e8_v1.css?1782399899792292" type="text/css" rel="stylesheet" data-template-style="true"/>\n\r\n\n\r\n\n\r\n\n\n<meta property="fb:app_id" content="1917364465060952"><meta property="og:title" content=""><meta property="og:type" content="article"><meta property="og:url" content="https://cbu.uz/oz/financial-stability/report/"><meta property="og:image" content="https://cbu.uz/upload/media/images/social.jpg"><meta property="og:site_name" content="\xd0\x8e\xd0\xb7\xd0\xb1\xd0\xb5\xd0\xba\xd0\xb8\xd1\x81\xd1\x82\xd0\xbe\xd0\xbd \xd0\xa0\xd0\xb5\xd1\x81\xd0\xbf\xd1\x83\xd0\xb1\xd0\xbb\xd0\xb8 ...

# %%
matn = response.text
matn
# Out:
# '<!DOCTYPE html>\n<html lang="oz" data-site-dir="/oz/">\n<head><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width, initial-scale=1"><title>Молиявий барқарорлик шарҳи - Ўзбекистон Республикаси Марказий банки</title><link rel="apple-touch-icon" sizes="180x180" href="/favicons/apple-touch-icon.png"><link rel="icon" type="image/svg+xml" sizes="120x120" href="/favicons/favicon-120x120.svg"><link rel="icon" type="image/png" sizes="96x96" href="/favicons/favicon-96x96.png"><link rel="icon" type="image/png" sizes="32x32" href="/favicons/favicon-32x32.png"><link rel="icon" type="image/png" sizes="16x16" href="/favicons/favicon-16x16.png"><link rel="manifest" href="/favicons/site.webmanifest"><meta name="msapplication-TileColor" content="#ffc700"><meta name="theme-color" content="#ffc700"><meta name="msapplication-config" content="/favicons/browserconfig.xml"><meta name="format-detection" content="telephone=no"><meta name="format-detection" content="date=no"><meta name="format-detection" content="address=no"><meta name="format-detection" content="email=no"><meta name="format-detection" content="telephone=no,date=no,address=no,email=no,url=no"><link href="/bitrix/templates/main/css/jquery.reject-1.1.0.min.css" type="text/css" rel="stylesheet" data-skip-moving="true">\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />\n<meta name="robots" content="index, follow" />\n<script data-skip-moving="true">(function(w, d, n) {var cl = "bx-core";var ht = d.documentElement;var htc = ht ? ht.className : undefined;if (htc === undefined || htc.indexOf(cl) !== -1){return;}var ua = n.userAgent;if (/(iPad;)|(iPhone;)/i.test(ua)){cl += " bx-ios";}else if (/Windows/i.test(ua)){cl += \' bx-win\';}else if (/Macintosh/i.test(ua)){cl += " bx-mac";}else if (/Linux/i.test(ua) && !/Android/i.test(ua)){cl += " bx-linux";}else if (/Android/i.test(ua)){cl += " bx-android";}cl += (/(ipad|iphone|android|mobile|touch)/i.test(ua) ? " bx-touch" : " bx-no-touch");cl += w.devicePixelRatio && w.devicePixelRatio >= 2? " bx-retina": " bx-no-retina";if (/Safari/i.test(ua) && !/Chrome/i.test(ua)){cl += " bx-safari";}else if (/AppleWebKit/.test(ua)){cl += " bx-chrome";}else if (/Opera/.test(ua)){cl += " bx-opera";}else if (/Firefox/.test(ua)){cl += " bx-firefox";}ht.className = htc ? htc + " " + cl : cl;})(window, document, navigator);</script>\n\n\n<link href="/bitrix/js/ui/design-tokens/dist/ui.design-tokens.min.css?172977453223463" type="text/css" rel="stylesheet"/>\n<link href="/bitrix/js/ui/fonts/opensans/ui.font.opensans.min.css?16778425832320" type="text/css" rel="stylesheet"/>\n<link href="/bitrix/js/main/popup/dist/main.popup.bundle.min.css?176951421628056" type="text/css" rel="stylesheet"/>\n<link href="/bitrix/js/altasib.errorsend/css/window.css?1694603798910" type="text/css" rel="stylesheet"/>\n<link href="/bitrix/cache/css/s4/main/template_1b6fdbb01d9a6a32a35de54a35f995e8/template_1b6fdbb01d9a6a32a35de54a35f995e8_v1.css?1782399899792292" type="text/css" rel="stylesheet" data-template-style="true"/>\n\r\n\n\r\n\n\r\n\n\n<meta property="fb:app_id" content="1917364465060952"><meta property="og:title" content=""><meta property="og:type" content="article"><meta property="og:url" content="https://cbu.uz/oz/financial-stability/report/"><meta property="og:image" content="https://cbu.uz/upload/media/images/social.jpg"><meta property="og:site_name" content="Ўзбекистон Республикаси Марказий банки"><meta property="og:description" content=""><link rel="image_src" href="https://cbu.uz/upload/media/images/social.jpg">\n</head>\n<body class="lang-oz is-inner">\n<div id="panel"></div>\n<div class="page">\n    <noindex>\n    <div class="special-settings" style="z-index: 2000">\n        <div class="special-settings-wrapper clearfix">\n            <div class="a-fontsize">\n                Шрифт ўлчами:\n                <a class="a-fontsize-small" data-set="fs-small" href="#" title="Кичик шрифт ўлчами">A</a>\n        ...

# %%
import json
info = json.loads(matn)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[21], line 2
#       1 import json
# ----> 2 info = json.loads(matn)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     347     s = s.decode(detect_encoding(s), 'surrogatepass')
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#     354     cls = JSONDecoder
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     340 def decode(self, s, _w=WHITESPACE.match):
#     341     """Return the Python representation of ``s`` (a ``str`` instance
#     342     containing a JSON document).
#     343
#     344     """
# --> 345     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346     end = _w(s, end).end()
#     347     if end != len(s):
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     361     obj, end = self.scan_once(s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:1116, in Response.json(self, **kwargs)
#    1115 try:
# -> 1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\json\__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\json\decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 response.json()
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:1120, in Response.json(self, **kwargs)
#    1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# -> 1120     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## Headers

# %%
response.headers
# Out:
# {'Server': 'nginx', 'Date': 'Sat, 27 Jun 2026 06:38:15 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'HTTPS', 'X-Powered-CMS': 'Bitrix Site Manager (c8adcaa7ec7e7ae69696ea11d0fec79f)', 'Set-Cookie': 'PHPSESSID=2Si2SGcztlvH6ySapxVv2Ryh1ON9pFOq; path=/; domain=cbu.uz; secure; HttpOnly, BITRIX_SM_GUEST_ID=91821298; expires=Tue, 22 Jun 2027 06:38:14 GMT; Max-Age=31103999; path=/; domain=cbu.uz, BITRIX_SM_LAST_VISIT=27.06.2026%2011%3A38%3A14; expires=Tue, 22 Jun 2027 06:38:14 GMT; Max-Age=31103999; path=/; domain=cbu.uz', 'Expires': 'Thu, 19 Nov 1981 08:52:00 GMT', 'Cache-Control': 'no-store, no-cache, must-revalidate', 'Pragma': 'no-cache', 'X-Frame-Options': 'SAMEORIGIN, SAMEORIGIN', 'Content-Security-Policy': "frame-ancestors 'self';", 'X-Content-Type-Options': 'nosniff', 'Content-Encoding': 'gzip'}

# %%
import requests

response = requests.get(
    'https://api.github.com/search/repositories',
    params={"q": 'requests + language:python'},
)

json_response = response.json()
repository = json_response['items'][0]
print(f'Repository name: {repository['name']}')
print(f'Repository description: {repository['description']}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 9
#       5     params={"q": 'requests language:python'},
#       6 )
#       7
#       8 json_response = response.json()
# ----> 9 repository = json_response['items'][0]
#      10 print(f'Repository name: {repository['name']}')
#      11 print(f'Repository description: {repository['description']}')
#
# KeyError: 'items'

# %%
requests.post('https://httpbin.org/post', data = {'key':'value'})
# Out:
# <Response [503]>
