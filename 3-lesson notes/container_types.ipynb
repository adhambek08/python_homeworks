# %% [markdown]
# # Container Types Intro

# %% [markdown]
# Container/Reference Types:
#
# - `list`
# - `tuple`
# - `dictionary`
# - `set`

# %%
fruits = ['apple', 'cherry', 'banana']
type(fruits)
# Out:
# list

# %%
numbers = [1,5,7,6]
type(numbers)
# Out:
# list

# %%
list('abc')
# Out:
# ['a', 'b', 'c']

# %%
my_str = 'abcd'

my_str.split('')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 my_str = 'abcd'
#       2
# ----> 3 my_str.split('')
#
# ValueError: empty separator

# %%
type(numbers[1])
# Out:
# int

# %%
numbers[::2]
# Out:
# [1, 7]

# %%
a = 5
b = a

print(id(a))
print(id(b))

a += 1 # a = a + 1

print(a)
print(b)

print(id(a))
print(id(b))
# Out:
# 140735307678760
# 140735307678760
# 6
# 5
# 140735307678792
# 140735307678760

# %%
a = [1,2,3]
a.append(4)
a.append(5)
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a = [1,2,3]
b = a # reference assignment

print(id(a))
print(id(b))

a.append(4)

print(a)
print(b)
# Out:
# 2151430693056
# 2151430693056
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
a = [1,2,3]
b = a.copy()

print(id(a))
print(id(b))
# Out:
# 2151430645696
# 2151431981312

# %%
x = [
    [1,'da'], 
    [3,4]
    ]
y= x.copy()
x[0].append(5)
print(x)
print(y)
# Out:
# [[1, 'da', 5], [3, 4]]
# [[1, 'da', 5], [3, 4]]

# %%
from copy import copy, deepcopy

x = [
    [1,'da'], 
    [3,4]
    ]
y= deepcopy(x)
x[0].append(5)
print(x)
print(y)
# Out:
# [[1, 'da', 5], [3, 4]]
# [[1, 'da'], [3, 4]]

# %% [markdown]
# ### List Methods
#
# - append()
# - clear()
# - copy()
# - count()
# - extend()
# - index()
# - insert()
# - pop()
# - remove()
# - reverse()
# - sort()

# %%
fruits = ['apple', 'banana', 'ananas']
fruits.append('cherry')
fruits
# Out:
# ['apple', 'banana', 'ananas', 'cherry']

# %%
fruits.count('apple')
# Out:
# 1

# %%
# fruits.append(['melon', 'ananas']) # alohida list qilib qo'shib qo'yadi
# fruits
# Out:
# ['apple', 'banana', 'cherry', ['melon', 'ananas']]

# %%
fruits.extend(['melon', 'ananas']) # list berish kerak va oxiridan qo'shib qo'yadi
fruits
# Out:
# ['apple', 'banana', 'ananas', 'cherry', 'melon', 'ananas']

# %%
# fruits.clear()

# %%
fruits.index('ananas', fruits.index('ananas')+1)
# Out:
# 5

# %%
a = fruits.pop()
a
# Out:
# 'ananas'

# %%
fruits
# Out:
# ['apple', 'banana', 'ananas', 'cherry', 'melon']

# %%
fruits.remove('melon')

# %%
fruits
# Out:
# ['apple', 'ananas', 'cherry']

# %%
fruits.remove(fruits[0])

# %%
fruits
# Out:
# ['ananas', 'cherry']

# %%
fruits.reverse() # in-place reverse

# %%
fruits
# Out:
# ['cherry', 'ananas']

# %%
fruits.sort()

# %%
fruits
# Out:
# ['ananas', 'cherry']

# %%
mevalar = ['banan', 'tarvuz', 'olma', 'ananas', 'ab', 'cvv']
sorted(mevalar, key=lambda x: len(x))
# Out:
# ['ab', 'cvv', 'olma', 'banan', 'tarvuz', 'ananas']

# %%
numbers = [6,4,3,2,7]
sorted(numbers, reverse=True)
# Out:
# [7, 6, 4, 3, 2]

# %%
numbers[0]=5
numbers
# Out:
# [5, 4, 3, 2, 7]

# %% [markdown]
# ## Tuple

# %%
a = (1,2,3)
type(a)
# Out:
# tuple

# %% [markdown]
# append, sort, pop, remove, extend, reverse, insert = mutate
#
# index, count => possible
#
# copy => does not work

# %%
empty_tuple = tuple()
empty_tuple
# Out:
# ()

# %%
# Tuple unpacking

id, title, artist_id = (1, 'For Those About to Tock We Solute', 1)
title
# Out:
# 'For Those About to Tock We Solute'

# %% [markdown]
# ## Dictionary

# %%
# key : value
person = {
    'name' : 'John',
    'email' : 'john@gmail.com',
    'age' : 50
}

type(person)
# Out:
# dict

# %%
person.keys()
# Out:
# dict_keys(['name', 'email', 'age'])

# %%
person.values()
# Out:
# dict_values(['John', 'john@gmail.com', 50])

# %%
person.items()
# Out:
# dict_items([('name', 'John'), ('email', 'john@gmail.com'), ('age', 50)])

# %%
dict([('name', 'John'), ('email', 'john@gmail.com'), ('age', 50)])
# Out:
# {'name': 'John', 'email': 'john@gmail.com', 'age': 50}

# %%
dict(name='Adam', age = 40)
# Out:
# {'name': 'Adam', 'age': 40}

# %%
person['lname']='Doe'

# %%
person
# Out:
# {'name': 'John', 'email': 'john@gmail.com', 'age': 50, 'lname': 'Doe'}

# %%
K1 = 1
K2 = False
K3 = 'key3'
K4 = (1,2,3)

d1 = {
    K1: 'a',
    K2: 'ab',
    K3: 'abc',
    K4: 'abcd'
}
d1
# Out:
# {1: 'a', False: 'ab', 'key3': 'abc', (1, 2, 3): 'abcd'}

# %%
d1[K4]
# Out:
# 'abcd'

# %% [markdown]
# ## SET - TOPLAM

# %%
letters = {'a', 'b', 'c', 'd', 'a', 'b'}
type(letters)
# Out:
# set

# %%
letters
# Out:
# {'a', 'b', 'c', 'd'}

# %%
s1 = {'a', 'b', 'c', 'd'}
s2 = {'r', 'a', 'b'}
s1.union(s2)
# Out:
# {'a', 'b', 'c', 'd', 'r'}

# %%
s1 | s2 == s1.union(s2)
# Out:
# True

# %%
s1.difference(s2)
# Out:
# {'c', 'd'}

# %%
s1 - s2
# Out:
# {'c', 'd'}

# %%
s1.symmetric_difference(s2)
# Out:
# {'c', 'd', 'r'}

# %%
s1 ^ s2
# Out:
# {'c', 'd', 'r'}

# %%
'apple' in s1
# Out:
# False

# %% [markdown]
# ## Namedtuple

# %%
from collections import namedtuple

Color = namedtuple('Color', ['x', 'y', 'z'])

white = Color(255, 255, 255)
black = Color(0, 0, 0)
green = Color(0, 255, 0)

green.y
# Out:
# 255

# %%
type(green)
# Out:
# __main__.Color

# %%
isinstance(green, tuple)
# Out:
# True
