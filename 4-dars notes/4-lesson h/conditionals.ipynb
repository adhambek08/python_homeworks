# %% [markdown]
# ```
# if <condition>:
#     <statements>
#     <statements>
# ```

# %%
authenticated = True

if authenticated:
    print('You\'re logged in')
# Out:
# You're logged in

# %%
age = 15

if age < 18:
    print('You can vote')
# Out:
# You can vote

# %%
age > 18
# Out:
# False

# %% [markdown]
# ```
# Tekshirish:
#     >
#     <
#     ==
#     >=
#     <=
#     !=
# ```

# %%
a = 1
if a:
    print('Truthy')
else:
    print('Falsy')
# Out:
# Truthy

# %%
x = 5
y = 5

print('ID x:', id(x))
print('ID y:', id(y))
# Out:
# ID x: 140727829824552
# ID y: 140727829824552

# %%
age = 17
car = 'BMW'

if age >= 18 and car in ['Honda', 'BMW', 'Toyota']:
    print('true')
else:
    print('false')
# Out:
# false

# %%
age = 17
car = 'BMW'

if age >= 18 or car in ['Honda', 'BMW', 'Toyota']:
    print('true')
else:
    print('false')
# Out:
# true

# %% [markdown]
# ```
# if <condition>:
# elif <condition>:
# elif <condition>:
# elif <condition>:
# else:
# ```

# %%
# order is important
age = 23

if age < 0:
    print('incorrect number for age. Age must be postive')
elif age < 18:
    print('You cannot vote')
elif age < 150:
    print('You can vote')
else:
    print('incorrect number for age')
# Out:
# You can vote
